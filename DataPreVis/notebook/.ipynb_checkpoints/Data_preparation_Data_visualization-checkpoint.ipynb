# %% [markdown]
# # Machine Learning for Health Insurance Example
#
# #### The visual analytic flow is taken from [Dandelion] (https://www.kaggle.com/hely333)
# #### The codes are edited by ASKS Data Science Group
# ##### Edited by ASKS Data Science Group

# %% [markdown]
# ## Step 1: Checking the data

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
insurance_data = pd.read_csv('../data/insurance_add_step.csv')
insurance_data.head()
# Out:
#     age   sex     bmi    steps  children  smoker     region      charges  \
# 0  19.0     0  27.900   3009.0       0.0       1  southwest  16884.92400
# 1  18.0  male  33.770   3008.0       1.0       0  southeast   1725.55230
# 2  28.0  male  33.000   3009.0       3.0       0  southeast   4449.46200
# 3  33.0  male  22.705  10009.0       NaN       0  northwest  21984.47061
# 4  32.0  male  28.880   8010.0       NaN       0  northwest   3866.85520
#
#    insuranceclaim
# 0             1.0
# 1             1.0
# 2             0.0
# 3             0.0
# 4             1.0

# %%
insurance_data.isnull().sum()
# Out:
# age                 5
# sex                 0
# bmi                 0
# steps              13
# children          104
# smoker              0
# region              0
# charges             2
# insuranceclaim      2
# dtype: int64

# %%
insurance_data.describe()
# Out:
#                age          bmi         steps     children       smoker  \
# count  1339.000000  1344.000000   1331.000000  1240.000000  1344.000000
# mean     39.222554    30.659446   5358.096920     1.185484     0.203869
# std      14.073363     6.093595   2456.921349     1.209773     0.403023
# min      18.000000    15.960000   2908.000000     0.000000     0.000000
# 25%      26.500000    26.308750   3009.000000     0.000000     0.000000
# 50%      39.000000    30.380000   4007.000000     1.000000     0.000000
# 75%      51.000000    34.681250   8004.000000     2.000000     0.000000
# max      64.000000    53.130000  10010.000000     5.000000     1.000000
#
#             charges  insuranceclaim
# count   1342.000000     1342.000000
# mean   13265.808050        0.584948
# std    12098.073122        0.492915
# min     1121.873900        0.000000
# 25%     4740.287150        0.000000
# 50%     9382.033000        1.000000
# 75%    16639.912515        1.000000
# max    63770.428010        1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = insurance_data.copy()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'steps', 'children', 'smoker', 'region', 'charges',
#        'insuranceclaim'],
#       dtype='object')

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C2E5E9320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C30A5A9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C30A8EE10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C30ACB3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C30AFC978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C30B2EF28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021C30B6A518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C30B9AB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021C30B9AB38>]],
#       dtype=object)

# %%
df.steps.hist()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'steps', 'children', 'smoker', 'region', 'charges',
#        'insuranceclaim'],
#       dtype='object')

# %%
df.sex.value_counts()
# Out:
# male      517
# female    502
# 0         162
# 1         161
# 11          2
# Name: sex, dtype: int64

# %%
df.smoker.value_counts()
# Out:
# 0    1070
# 1     274
# Name: smoker, dtype: int64

# %%
df.region.value_counts()
# Out:
# southeast    365
# northwest    328
# northeast    326
# southwest    325
# Name: region, dtype: int64

# %%
df.age.hist()

# %%
df.age.mean()
# Out:
# 39.22255414488424

# %%
df.isnull().sum()
# Out:
# age                 5
# sex                 0
# bmi                 0
# steps              13
# children          104
# smoker              0
# region              0
# charges             2
# insuranceclaim      2
# dtype: int64

# %% [markdown]
# ### Preparing the data
#
# Now that we've looked at the data set, we need to prepare them before we proceed with the analysis for both the regression, and the classification. Again, we will use the DataFrame for both tasks.

# %% [markdown]
# ### 1.1 Missing values

# %% [markdown]
# ##### 1.1.1 Fillna

# %%
df['age'].fillna(39, inplace=True)

# %%
df.isnull().sum()
# Out:
# age                 0
# sex                 0
# bmi                 0
# steps              13
# children          104
# smoker              0
# region              0
# charges             2
# insuranceclaim      2
# dtype: int64

# %%
df[df.steps.isnull()].age.hist()

# %%
df.steps.min()
# Out:
# 2908.0

# %%
min_steps = df[ (df.age >=20) & (df.age <=40)].steps.min()

# %%
df['steps'].fillna(min_steps, inplace=True)

# %%
df.isnull().sum()
# Out:
# age                 0
# sex                 0
# bmi                 0
# steps               0
# children          104
# smoker              0
# region              0
# charges             2
# insuranceclaim      2
# dtype: int64

# %%
df[df.children.isnull()]
# Out:
#        age     sex     bmi    steps  children  smoker     region      charges  \
# 3     33.0    male  22.705  10009.0       NaN       0  northwest  21984.47061
# 4     32.0    male  28.880   8010.0       NaN       0  northwest   3866.85520
# 10    25.0    male  26.220   8006.0       NaN       0  northeast   2721.32080
# 11    62.0  female  26.290   5004.0       NaN       1  southeast  27808.72510
# 12    23.0       1  34.400   3008.0       NaN       0  southwest   1826.84300
# ...    ...     ...     ...      ...       ...     ...        ...          ...
# 1305  43.0       1  27.800   4009.0       NaN       1  southwest  37829.72420
# 1308  29.0  female  21.850   3007.0       NaN       1  northeast  16115.30450
# 1319  18.0    male  53.130   3005.0       NaN       0  southeast   1163.46270
# 1337  18.0  female  36.850   3008.0       NaN       0  southeast   1629.83350
# 1339  61.0  female  29.070   8008.0       NaN       1  northwest  29141.36030
#
#       insuranceclaim
# 3                0.0
# 4                1.0
# 10               1.0
# 11               1.0
# 12               1.0
# ...              ...
# 1305             1.0
# 1308             1.0
# 1319             1.0
# 1337             1.0
# 1339             1.0
#
# [104 rows x 9 columns]

# %%
df['children'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# age               0
# sex               0
# bmi               0
# steps             0
# children          0
# smoker            0
# region            0
# charges           2
# insuranceclaim    2
# dtype: int64

# %% [markdown]
# ##### 1.2 Drop all NA

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# age               0
# sex               0
# bmi               0
# steps             0
# children          0
# smoker            0
# region            0
# charges           0
# insuranceclaim    0
# dtype: int64

# %%
df.sex.value_counts()
# Out:
# male      515
# female    502
# 0         162
# 1         161
# 11          2
# Name: sex, dtype: int64

# %% [markdown]
# ### 1.2 Invalid values

# %% [markdown]
# ##### 1.2.1 Replace values

# %%
 df['sex'].replace('0','female', inplace=True)

# %%
 df['sex'].replace('1','male', inplace=True)

# %%
 df['sex'].replace('11','male', inplace=True)

# %%
df.sex.value_counts()
# Out:
# male      678
# female    664
# Name: sex, dtype: int64

# %%
df.head()
# Out:
#     age     sex     bmi    steps  children  smoker     region      charges  \
# 0  19.0  female  27.900   3009.0       0.0       1  southwest  16884.92400
# 1  18.0    male  33.770   3008.0       1.0       0  southeast   1725.55230
# 2  28.0    male  33.000   3009.0       3.0       0  southeast   4449.46200
# 3  33.0    male  22.705  10009.0       0.0       0  northwest  21984.47061
# 4  32.0    male  28.880   8010.0       0.0       0  northwest   3866.85520
#
#    insuranceclaim
# 0             1.0
# 1             1.0
# 2             0.0
# 3             0.0
# 4             1.0

# %%
df.dtypes
# Out:
# age               float64
# sex                object
# bmi               float64
# steps             float64
# children          float64
# smoker              int64
# region             object
# charges           float64
# insuranceclaim    float64
# dtype: object

# %% [markdown]
# ### 1.3 Transform data

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()
df['sex_code'] = lb_make.fit_transform(df['sex'])
df['region_code'] = lb_make.fit_transform(df['region'])

# %%
df.head()
# Out:
#     age     sex     bmi    steps  children  smoker     region      charges  \
# 0  19.0  female  27.900   3009.0       0.0       1  southwest  16884.92400
# 1  18.0    male  33.770   3008.0       1.0       0  southeast   1725.55230
# 2  28.0    male  33.000   3009.0       3.0       0  southeast   4449.46200
# 3  33.0    male  22.705  10009.0       0.0       0  northwest  21984.47061
# 4  32.0    male  28.880   8010.0       0.0       0  northwest   3866.85520
#
#    insuranceclaim  sex_code  region_code
# 0             1.0         0            3
# 1             1.0         1            2
# 2             0.0         1            2
# 3             0.0         1            1
# 4             1.0         1            1

# %%
df = df.drop(columns=['sex','region'])

# %%
df.dtypes
# Out:
# age               float64
# bmi               float64
# steps             float64
# children          float64
# smoker              int64
# charges           float64
# insuranceclaim    float64
# sex_code            int32
# region_code         int32
# dtype: object

# %% [markdown]
# ## Step 2: The Visualization

# %% [markdown]
# #### 2.1 Scatter Plot
#
# One of the first plot that we can try is scatter plot to see the relationship between 2 variables

# %%
import seaborn as sns
plt.subplots(figsize=(12, 8))
sns.set(font_scale=1.2)
ax = sns.scatterplot(x="bmi", y="charges", hue='insuranceclaim', data=df)

# %% [markdown]
# #### 2.2 Correlation Heat Map
#
# Next we will plot the correlation value between features as heatmap. (Dataframe has .corr() function for the correlation.)

# %%
import seaborn as sns
import numpy as np

fi, axis = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(200,10,as_cmap=True), 
           square=True, ax=axis)

# %% [markdown]
# #### 2.3 Distribution Map
#
# Representation of the distribution of numerical data in one variable.<br>
# We can use 2 libraries for plotting distribution map <br>
# 1. matplotlib
# 2. seaborn

# %%
plt.hist(df.age, bins='auto') 
plt.title("The histogram showing the distribution of age")
plt.xlabel('age')
plt.ylabel('frequencies')
plt.show()

# %%
sns.distplot(df.age)
plt.title("The histogram showing the distribution of age")
# Out:
# Text(0.5, 1.0, 'The histogram showing the distribution of age')

# %% [markdown]
# We use distribution map to compare the data between smoker and non-smoker by using subplot.

# %%
fi= plt.figure(figsize=(14,5))

axis=fi.add_subplot(121)
sns.distplot(df[(df.smoker == 0)]['charges'],color='b',ax=axis)
axis.set_title('The distribution of the medical charges for the non-smokers')

axis=fi.add_subplot(122)
sns.distplot(df[(df.smoker == 1)]['charges'],color='c',ax=axis)
axis.set_title('The distribution of the medical charges for the smokers')
# Out:
# Text(0.5, 1.0, 'The distribution of the medical charges for the smokers')

# %% [markdown]
# ### 2.4 Plotting with Categorical data
#
# To show the relationship between multiple variables in a dataset, one of the main variables is “categorical” (divided into discrete groups)<br>
# There are many kinds of catplot, the example are:
# 1. count
# 2. bar
# 3. box
# 4. swarm
# 5. violin

# %% [markdown]
# ##### Bar

# %%
sns.catplot(x='smoker', y='steps', hue='insuranceclaim', kind='bar', palette="inferno", data=df)
plt.title('xxx')
# Out:
# Text(0.5, 1, 'xxx')

# %% [markdown]
# ##### Count

# %%
sns.catplot(x="smoker", kind="count",hue = 'sex_code', palette="inferno", data=df)

# %%
sns.catplot(x="smoker", kind="count",hue = 'sex_code', palette="rainbow", data=df[(df.age == 18)])
plt.title("The number of smokers and non-smokers (18 years old)")
# Out:
# Text(0.5, 1, 'The number of smokers and non-smokers (18 years old)')

# %%
sns.catplot(x="children", kind="count", palette="ch:.25", data=df, size = 6)

# %%
sns.catplot(x="smoker", kind="count", palette="rainbow",hue = "sex_code",
            data=df[(df.children > 0)], size = 6)
ax.set_title('Smokers and non-smokers who have childrens')
# Out:
# Text(0.5, 1, 'Smokers and non-smokers who have childrens')

# %% [markdown]
# ##### Swarm

# %%
sns.catplot(x="sex_code", y="charges", hue="smoker", kind="swarm", palette = 'inferno', data=df)

# %% [markdown]
# ##### Violin

# %%
sns.catplot(x="sex_code", y="charges", hue="smoker", kind="violin", palette = 'inferno', data=df)

# %% [markdown]
# ##### Box

# %%
sns.catplot(x='charges', y='smoker', data=df[(df.sex_code == 1)] , orient='h', kind='box' , palette = 'inferno', 
           height=5, aspect=2)
plt.title("The box plot of males' medical charges")
# Out:
# Text(0.5, 1, "The box plot of males' medical charges")

# %% [markdown]
# ### 2.5 Boxplot

# %%
plt.figure(figsize=(12,5))
sns.boxplot(y="smoker", x="charges", data = df[(df.sex_code == 1)] 
            ,orient="h", palette = 'inferno')
plt.title("The box plot of males' medical charges")
# Out:
# Text(0.5, 1.0, "The box plot of males' medical charges")

# %%
plt.figure(figsize=(12,5))
plt.title("The box plot of females' medical charges")
sns.boxplot(y="smoker", x="charges", data = df[(df.sex_code == 0)] 
            ,orient="h", palette = 'inferno')

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges 18 years old smokers")
sns.boxplot(y="smoker", x="charges", data = df[(df.age == 18)] , orient="h", palette = 'pink')

# %% [markdown]
# ### 2.6 JointPlot

# %%
g = sns.jointplot(x="age", y="charges", data = df[(df.smoker == 1)],kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$Age$", "$Charges$")
ax.set_title('Distribution of charges and age for smokers')
# Out:
# Text(0.5, 1, 'Distribution of charges and age for smokers')

# %%
g = sns.jointplot(x="age", y="charges", data = df[(df.smoker == 0)],kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$")
ax.set_title('Distribution of charges and age for non-smokers')
# Out:
# Text(0.5, 1, 'Distribution of charges and age for non-smokers')

# %% [markdown]
# # Exercise
#
# Explore the relationship between other variables in the current data using other pairs of features using one catplot per a relationship.
# Hence, you must plot one graph per the following type of catplot:
# 1. count
# 2. bar
# 3. box
# 4. swarm
# 5. violin

# %%
sns.catplot(x="smoker", kind="count",hue = 'insuranceclaim', palette="rainbow", data=df)
plt.title("The count plot")
# Out:
# Text(0.5, 1, 'The count plot')

# %%
sns.catplot(x='smoker', y='steps', hue='insuranceclaim', kind='bar', palette="inferno", data=df)
plt.title('bar')
# Out:
# Text(0.5, 1, 'bar')

# %%
sns.catplot(x='charges', data=df[(df.sex_code == 1)] , orient='h', kind='box' , palette = 'rainbow', 
           height=5, aspect=2)
plt.title("The Box plot")
# Out:
# Text(0.5, 1, 'The Box plot')

# %%
sns.catplot(x="sex_code", y="bmi", hue="insuranceclaim", kind="swarm", palette = 'rainbow', data=df)
plt.title("The Swarm plot")
# Out:
# Text(0.5, 1, 'The Swarm plot')

# %%
sns.catplot(x="smoker", y="bmi", hue="region_code", kind="violin", palette = 'rainbow', data=df)
plt.title("The Violin plot")
# Out:
# Text(0.5, 1, 'The Violin plot')
